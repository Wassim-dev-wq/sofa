# %%
import pandas as pd
# Read the data
df = pd.read_csv('Merged/Cleaned/merged_all.csv')
df.head()
# Out:
#    winnerCode  attendance  defaultPeriodCount  defaultPeriodLength  \
# 0           1     16989.0                   2                   45
# 1           1     16989.0                   2                   45
# 2           1     16989.0                   2                   45
# 3           1     16989.0                   2                   45
# 4           1     16989.0                   2                   45
#
#    fanRatingEvent  tournament.category.id  \
# 0           False                    1468
# 1           False                    1468
# 2           False                    1468
# 3           False                    1468
# 4           False                    1468
#
#    tournament.uniqueTournament.category.id  \
# 0                                     1468
# 1                                     1468
# 2                                     1468
# 3                                     1468
# 4                                     1468
#
# ...

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['winnerCode'],df['attendance'])
